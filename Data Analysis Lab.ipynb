# %% [markdown]
# <center>
#     <img src="https://gitlab.com/ibm/skills-network/courses/placeholder101/-/raw/master/labs/module%201/images/IDSNlogo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # **Exploratory Data Analysis Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this module you get to work with the cleaned dataset from the previous module.
#
# In this assignment you will perform the task of exploratory data analysis.
# You will find out the distribution of data, presence of outliers and also determine the correlation between different columns in the dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Identify the distribution of data in the dataset.
#
# -   Identify outliers in the dataset.
#
# -   Remove outliers from the dataset.
#
# -   Identify correlation between features in the dataset.

# %% [markdown]
# * * *

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import the pandas module.

# %%
import pandas as pd

# %% [markdown]
# Load the dataset into a dataframe.

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")

# %% [markdown]
# ## Distribution

# %% [markdown]
# ### Determine how the data is distributed

# %% [markdown]
# The column `ConvertedComp` contains Salary converted to annual USD salaries using the exchange rate on 2019-02-01.
#
# This assumes 12 working months and 50 working weeks.

# %% [markdown]
# Plot the distribution curve for the column `ConvertedComp`.

# %%
# your code goes here
df.plot(figsize=(20,10),style=('.-'),fontsize=16).legend(fontsize=16)

# %% [markdown]
# Plot the histogram for the column `ConvertedComp`.

# %%
# your code goes here
df.hist(figsize=(20,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4c4ab62290>,
# ...
#       dtype=object)

# %% [markdown]
# What is the median of the column `ConvertedComp`?

# %%
# your code goes here
df['ConvertedComp'].median()
# Out:
# 57745.0

# %% [markdown]
# How many responders identified themselves only as a **Man**?

# %%
# your code goes here
df['Gender'].value_counts()
# Out:
# Man                                                            10480
# Woman                                                            731
# Non-binary, genderqueer, or gender non-conforming                 63
# Man;Non-binary, genderqueer, or gender non-conforming             26
# Woman;Non-binary, genderqueer, or gender non-conforming           14
# Woman;Man                                                          9
# Woman;Man;Non-binary, genderqueer, or gender non-conforming        2
# Name: Gender, dtype: int64

# %% [markdown]
# Find out the  median ConvertedComp of responders identified themselves only as a **Woman**?

# %%
# your code goes here
df.loc[(df['Gender']=='Woman'),'ConvertedComp'].median()
# Out:
# 57708.0

# %% [markdown]
# Give the five number summary for the column `Age`?

# %% [markdown]
# **Double click here for hint**.
#
# <!--
# min,q1,median,q3,max of a column are its five number summary.
# -->

# %%
# your code goes here
print('Minimum: ',df['Age'].min())
print('Maximum: ',df['Age'].max())
print('Median: ',df['Age'].median())
print('Q1: ',df['Age'].quantile([.25,.50,.75]).values[0])
print('Q3: ',df['Age'].quantile([.25,.50,.75]).values[2])
# Out:
# Minimum:  16.0
# Maximum:  99.0
# Median:  29.0
# Q1:  25.0
# Q3:  35.0

# %% [markdown]
# Plot a histogram of the column `Age`.

# %%
# your code goes here
df['Age'].hist(figsize=(20,10),xlabelsize=16,ylabelsize=16)

# %% [markdown]
# ## Outliers

# %% [markdown]
# ### Finding outliers

# %% [markdown]
# Find out if outliers exist in the column `ConvertedComp` using a box plot?

# %%
# your code goes here
df.boxplot(figsize=(20,10),column=['ConvertedComp'],fontsize=16)

# %% [markdown]
# Find out the Inter Quartile Range for the column `ConvertedComp`.

# %%
# your code goes here
[Q1,Q3]=df['ConvertedComp'].quantile([0.25,0.75])
print('Inter Quartile: ',Q3-Q1)
# Out:
# Inter Quartile:  73132.0

# %% [markdown]
# Find out the upper and lower bounds.

# %%
# your code goes here
IQR = Q3-Q1
lower_bound = Q1 - (1.5*(IQR))
upper_bound = Q3 + (1.5*(IQR))
print('LowerBound: ',lower_bound,'\nUpperBound: ',upper_bound)
# Out:
# LowerBound:  -82830.0
# UpperBound:  209698.0

# %% [markdown]
# Identify how many outliers are there in the `ConvertedComp` column.

# %%
# your code goes here
df.loc[
        (df['ConvertedComp'] < lower_bound),
    'Outliers'] = 'outlier'
df.loc[
        (df['ConvertedComp'] > upper_bound),
    'Outliers'] = 'outlier'
df['Outliers'].value_counts()
# Out:
# outlier    879
# Name: Outliers, dtype: int64

# %% [markdown]
# Create a new dataframe by removing the outliers from the `ConvertedComp` column.

# %%
# your code goes here
df['Outliers'] = df['Outliers'].fillna('')
data = df.loc[(df['Outliers']!='outlier')]
print(df.shape[0],data.shape[0])
# Out:
# 11398 10519

# %% [markdown]
# ## Correlation

# %% [markdown]
# ### Finding correlation

# %% [markdown]
# Find the correlation between `Age` and all other numerical columns.

# %%
# your code goes here
data.corr(method = 'kendall')
# Out:
#                Respondent  CompTotal  ConvertedComp  WorkWeekHrs  CodeRevHrs  \
# Respondent       1.000000  -0.005927       0.007277    -0.007014   -0.000623
# CompTotal       -0.005927   1.000000       0.394995     0.129066    0.033693
# ConvertedComp    0.007277   0.394995       1.000000     0.060500   -0.048913
# WorkWeekHrs     -0.007014   0.129066       0.060500     1.000000    0.103370
# CodeRevHrs      -0.000623   0.033693      -0.048913     0.103370    1.000000
# Age              0.000835   0.144379       0.304552     0.057124    0.010778
#
#                     Age
# Respondent     0.000835
# CompTotal      0.144379
# ConvertedComp  0.304552
# WorkWeekHrs    0.057124
# CodeRevHrs     0.010778
# Age            1.000000

# %%
data.corr(method = 'pearson')
# Out:
#                Respondent  CompTotal  ConvertedComp  WorkWeekHrs  CodeRevHrs  \
# Respondent       1.000000  -0.019364       0.010878    -0.015275    0.002980
# CompTotal       -0.019364   1.000000      -0.063561     0.004975    0.017536
# ConvertedComp    0.010878  -0.063561       1.000000     0.034351   -0.088934
# WorkWeekHrs     -0.015275   0.004975       0.034351     1.000000    0.031963
# CodeRevHrs       0.002980   0.017536      -0.088934     0.031963    1.000000
# Age              0.003950   0.006371       0.401821     0.037452   -0.017961
#
#                     Age
# Respondent     0.003950
# CompTotal      0.006371
# ConvertedComp  0.401821
# WorkWeekHrs    0.037452
# CodeRevHrs    -0.017961
# Age            1.000000

# %%
print('What is the median Age of survey respondents? ',df['Age'].median())
print('What is the median ConvertedComp of respondents who have identified themselves as ‘Woman’? ',df.loc[(df['Gender']=='Woman'),'ConvertedComp'].median())
print('Based on the histogram, which age group has the highest number of survey respondents?')
df['Age'].hist(figsize=(20,10),xlabelsize=18,ylabelsize=16)
# Out:
# What is the median Age of survey respondents?  29.0
# What is the median ConvertedComp of respondents who have identified themselves as ‘Woman’?  57708.0
# Based on the histogram, which age group has the highest number of survey respondents?

# %%
print('What is the median ConvertedComp before removing outliers?',df['ConvertedComp'].median())
print('What is the median ConvertedComp after removing outliers?',data['ConvertedComp'].median())
print('What is the median ConvertedComp after removing outliers?',data['ConvertedComp'].mean())
data.boxplot(figsize=(20,10),column=['Age'],fontsize=16)
# Out:
# What is the median ConvertedComp before removing outliers? 57745.0
# What is the median ConvertedComp after removing outliers? 52704.0
# What is the median ConvertedComp after removing outliers? 59883.20838915799

# %%
data.corr(method = 'pearson')
# Out:
#                Respondent  CompTotal  ConvertedComp  WorkWeekHrs  CodeRevHrs  \
# Respondent       1.000000  -0.019364       0.010878    -0.015275    0.002980
# CompTotal       -0.019364   1.000000      -0.063561     0.004975    0.017536
# ConvertedComp    0.010878  -0.063561       1.000000     0.034351   -0.088934
# WorkWeekHrs     -0.015275   0.004975       0.034351     1.000000    0.031963
# CodeRevHrs       0.002980   0.017536      -0.088934     0.031963    1.000000
# Age              0.003950   0.006371       0.401821     0.037452   -0.017961
#
#                     Age
# Respondent     0.003950
# CompTotal      0.006371
# ConvertedComp  0.401821
# WorkWeekHrs    0.037452
# CodeRevHrs    -0.017961
# Age            1.000000

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
#  Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
